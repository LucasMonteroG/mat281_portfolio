# %% [markdown]
# <img src="images/usm.jpg" width="480" height="240" align="left"/>

# %% [markdown]
# # MAT281 - Laboratorio N°05
#
# ## Objetivos de la clase
#
# * Reforzar los conceptos básicos de visualización.

# %% [markdown]
# ## Contenidos
#
# * [Problema 01](#p1)

# %% [markdown]
# ## Problema 01
#
# <img src="http://nelsoncos.com/wp-content/uploads/2017/02/sales-icon.png" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `company_sales_data.csv`, el cual contiene información tal como: número del mes, unidades, precio, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(10,8)})

# %%
# cargar datos
df = pd.read_csv(os.path.join("data","company_sales_data.csv"))
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:
#
# **Observación.-** Puedes ocupar las librerías de Matplolib o Seaborn.

# %% [markdown]
# 1. Lea el "total_profit" de todos los meses, muéstrelo usando un gráfico lineal y un gráfico de dispersión.

# %%
sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='total_profit',                          # En y utilizamos el registro de la ganancia por mes
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

# %%
sns.scatterplot(                               # Utilizo Seaborn con puntos
    x='month_number',                          # En x utilizamos el registro de los meses
    y='total_profit',                          # En y utilizamos el registro de la ganancia por mes
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

# %% [markdown]
# 2. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico multilínea.

# %%
palette = sns.color_palette("hls", 6)

sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='facecream',                             # En y utilizamos el registro de la ganancia por mes del producto
    #hue='facecream',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='facewash',                              # En y utilizamos el registro de la ganancia por mes del producto
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='toothpaste',                            # En y utilizamos el registro de la ganancia por mes del producto
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='bathingsoap',                           # En y utilizamos el registro de la ganancia por mes del producto
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='shampoo',                               # En y utilizamos el registro de la ganancia por mes del producto
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

sns.lineplot(                                  # Utilizo Seaborn con linea
    x='month_number',                          # En x utilizamos el registro de los meses
    y='moisturizer',                           # En y utilizamos el registro de la ganancia por mes del producto
    #hue='Generation',# color por Generation   
    data=df,                                   # Últilizamos nuestra data
    ci = None,                  
    palette=palette                            
)

# %% [markdown]
# 3. Lea los datos de ventas de productos de "facecream" y "facewash" y muéstrelos usando el gráfico de barras.

# %%
sns.barplot(                            # Utilizo Seaborn con barra
    x='month_number',                   # En x utilizamos el registro de los meses
    y='facecream',                      # En y utilizamos el registro de facecream
    data=df                             # Últilizamos nuestra data
)

# %%
sns.barplot(                            # Utilizo Seaborn con barra
    x='month_number',                   # En x utilizamos el registro de los meses
    y='facewash',                       # En y utilizamos el registro de facewash
    data=df                             # Últilizamos nuestra data
)

# %% [markdown]
# 4. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico box-plot.

# %%
#month_number	facecream	facewash	toothpaste	bathingsoap	shampoo	moisturizer	total_units	total_profit

# Pre-format DataFrame
stats_df = df.drop(['month_number', 'total_units', 'total_profit'], axis=1) # Quitamos de nuestra data lo que 
                                                                            # no necesitamos
 
# New boxplot using stats_df
sns.boxplot(data=stats_df)                                                  # Utilizamos Seaborn con cajas

# %% [markdown]
# 5. Calcule los datos de ventas totales del año pasado para cada producto y muéstrelos usando un gráfico circular

# %%
# Pre-format DataFrame
stats_df = df.drop(['month_number', 'total_units', 'total_profit'], axis=1)
 
# New boxplot using stats_df
sns.pieplot(data=stats_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-f67946e1f1ca> in <module>
#       3
#       4 # New boxplot using stats_df
# ----> 5 sns.pieplot(data=stats_df)
#
# AttributeError: module 'seaborn' has no attribute 'pieplot'
